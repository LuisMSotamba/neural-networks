# %%
import cv2
import os
import shutil
import numpy as np
import pandas as pd

from pathlib import Path

# %%
# read labels dataframe
labels_path = Path("/mnt/f/Datasets/Tesis/labels_df.pkl")
df_images = pd.read_pickle(labels_path)
df_images.head()
# Out:
#       video  frame    class  exist
# 0  IMG_03_1      0  LG-T-DW   True
# 1  IMG_03_1      6   LG-T-O   True
# 2  IMG_03_1     12   LG-T-O   True
# 3  IMG_03_1     18   LG-T-O   True
# 4  IMG_03_1     24   LG-T-O   True

# %%
def sampling_frames_per_video(
    df_video, 
    base_folder, 
    output_folder, 
    threshold=15.0, 
    blurry_score=100
):
    # create output folder if it doesn't exist
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    count = 0
    saved_count = 0
    last_saved_frame = None

    # sort dataframe by frames
    _df_video = df_video.sort_values(by=['frame'])
    _df_video.info()

    # iterate over each frame of the video group
    for idx, row in _df_video.iterrows():
        image_name = f"['{row['video']}'] frame {row['frame']}.jpg"
        image_path = base_folder / row["class"] / image_name
        gray = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        
        if last_saved_frame is None:
            is_distinct = True
        else:
            # compute laplacian variance and adaptive similarity sampling
            diff = np.mean(np.abs(gray - last_saved_frame))
            is_distinct = diff > threshold
            if not is_distinct:
                laplacian = cv2.Laplacian(gray, cv2.CV_64F)
                score = laplacian.var()
                is_distinct = score > blurry_score

        # copy image to the output dir if it is distinct from the last frame read
        if is_distinct:
             # create the subfolder in the output folder
            target_subfolder_path = Path(output_folder, row["class"])
            
            if not os.path.exists(target_subfolder_path):
                os.makedirs(target_subfolder_path)
            
            copy_image_path = Path(target_subfolder_path, image_name)
            shutil.copy(image_path, copy_image_path)
            
            last_saved_frame = gray
            saved_count += 1
            if saved_count % 100 == 0:
                print(f"Saved {saved_count} frames...")
        
        count += 1

    print(f"Finished. Scanned {count} frames, saved {saved_count} distinct images.")

# %%
# sampling frames per videos based on similarity measurements:
# adaptive similarity sampling and laplacian variance
df_images.groupby('video', group_keys=False).apply(
    lambda df_video: sampling_frames_per_video(
        df_video=df_video,
        base_folder=Path("F:\\ExoNet_Images\\ExoNet_Images"),
        output_folder=Path("F:\\ExoNet_Images_curated"),
        threshold=80.0, 
        blurry_score=300
    ), include_groups=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19436 entries, 417712 to 437147
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   video   19436 non-null  object
#  1   frame   19436 non-null  int64
#  2   class   19436 non-null  object
#  3   exist   19436 non-null  bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 626.4+ KB
# Saved 100 frames...
# Saved 200 frames...
# Saved 300 frames...
# Saved 400 frames...
# Saved 500 frames...
# Saved 600 frames...
# Saved 700 frames...
# Saved 800 frames...
# Saved 900 frames...
# Saved 1000 frames...
# Saved 1100 frames...
# Saved 1200 frames...
# Saved 1300 frames...
# Saved 1400 frames...
# Saved 1500 frames...
# Saved 1600 frames...
# Saved 1700 frames...
# Saved 1800 frames...
# Saved 1900 frames...
# Saved 2000 frames...
# Saved 2100 frames...
# Saved 2200 frames...
# Saved 2300 frames...
# Saved 2400 frames...
# Saved 2500 frames...
# Saved 2600 frames...
# Saved 2700 frames...
# Saved 2800 frames...
# Saved 2900 frames...
# Saved 3000 frames...
# Saved 3100 frames...
# Saved 3200 frames...
# Saved 3300 frames...
# Saved 3400 frames...
# Saved 3500 frames...
# Saved 3600 frames...
# Saved 3700 frames...
# Saved 3800 frames...
# Saved 3900 frames...
# Saved 4000 frames...
# Saved 4100 frames...
# Saved 4200 frames...
# Saved 4300 frames...
# Saved 4400 frames...
# Saved 4500 frames...
# Saved 4600 frames...
# Saved 4700 frames...
# Saved 4800 frames...
# Saved 4900 frames...
# Saved 5000 frames...
# Saved 5100 frames...
# Saved 5200 frames...
# Saved 5300 frames...
# Saved 5400 frames...
# Saved 5500 frames...
# Saved 5600 frames...
# Saved 5700 frames...
# Saved 5800 frames...
# Saved 5900 frames...
# Saved 6000 frames...
# Saved 6100 frames...
# Saved 6200 frames...
# Saved 6300 frames...
# Saved 6400 frames...
# Saved 6500 frames...
# Saved 6600 frames...
# Saved 6700 frames...
# Saved 6800 frames...
# Saved 6900 frames...
# Saved 7000 frames...
# Saved 7100 frames...
# Saved 7200 frames...
# Saved 7300 frames...
# Saved 7400 frames...
# Saved 7500 frames...
# Saved 7600 frames...
# Saved 7700 frames...
# Saved 7800 frames...
# Saved 7900 frames...
# Saved 8000 frames...
# Saved 8100 frames...
# Saved 8200 frames...
# Saved 8300 frames...
# Saved 8400 frames...
# Saved 8500 frames...
# Saved 8600 frames...
# Saved 8700 frames...
# Saved 8800 frames...
# Saved 8900 frames...
# Saved 9000 frames...
# Saved 9100 frames...
# Saved 9200 frames...
# Saved 9300 frames...
# Saved 9400 frames...
# Saved 9500 frames...
# Saved 9600 frames...
# Saved 9700 frames...
# Saved 9800 frames...
# Saved 9900 frames...
# Saved 10000 frames...
# Saved 10100 frames...
# Saved 10200 frames...
# Saved 10300 frames...
# Saved 10400 frames...
# Saved 10500 frames...
# Saved 10600 frames...
# Saved 10700 frames...
# Saved 10800 frames...
# Saved 10900 frames...
# Saved 11000 frames...
# Saved 11100 frames...
# Saved 11200 frames...
# Saved 11300 frames...
# Saved 11400 frames...
# Saved 11500 frames...
# Saved 11600 frames...
# Saved 11700 frames...
# Saved 11800 frames...
# Saved 11900 frames...
# Saved 12000 frames...
# Saved 12100 frames...
# Saved 12200 frames...
# Saved 12300 frames...
# Saved 12400 frames...
# Saved 12500 frames...
# Saved 12600 frames...
# Saved 12700 frames...
# Saved 12800 frames...
# Saved 12900 frames...
# Saved 13000 frames...
# Saved 13100 frames...
# Saved 13200 frames...
# Saved 13300 frames...
# Saved 13400 frames...
# Saved 13500 frames...
# Saved 13600 frames...
# Saved 13700 frames...
# Saved 13800 frames...
# Saved 13900 frames...
# Saved 14000 frames...
# Saved 14100 frames...
# Saved 14200 frames...
# Saved 14300 frames...
# Saved 14400 frames...
# Saved 14500 frames...
# Saved 14600 frames...
# Saved 14700 frames...
# Saved 14800 frames...
# Saved 14900 frames...
# Saved 15000 frames...
# Saved 15100 frames...
# Saved 15200 frames...
# Saved 15300 frames...
# Saved 15400 frames...
# Saved 15500 frames...
# Saved 15600 frames...
# Saved 15700 frames...
# Saved 15800 frames...
# Saved 15900 frames...
# Saved 16000 frames...
# Saved 16100 frames...
# Saved 16200 frames...
# Saved 16300 frames...
# Saved 16400 frames...
# Saved 16500 frames...
# Saved 16600 frames...
# Saved 16700 frames...
# Saved 16800 frames...
# Saved 16900 frames...
# Saved 17000 frames...
# Saved 17100 frames...
# Saved 17200 frames...
# Saved 17300 frames...
# Saved 17400 frames...
# Saved 17500 frames...
# Saved 17600 frames...
# Saved 17700 frames...
# Saved 17800 frames...
# Saved 17900 frames...
# Saved 18000 frames...
# Saved 18100 frames...
# Saved 18200 frames...
# Saved 18300 frames...
# Saved 18400 frames...
# Finished. Scanned 19436 frames, saved 18453 distinct images.
# <class 'pandas.core.frame.DataFrame'>
# Index: 11074 entries, 765380 to 776453
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   video   11074 non-null  object
#  1   frame   11074 non-null  int64
#  2   class   11074 non-null  object
#  3   exist   11074 non-null  bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 356.9+ KB
# Saved 100 frames...
# Saved 200 frames...
# Saved 300 frames...
# Saved 400 frames...
# Saved 500 frames...
# Saved 600 frames...
# Saved 700 frames...
# Saved 800 frames...
# Saved 900 frames...
# Saved 1000 frames...
# Saved 1100 frames...
# Saved 1200 frames...
# Saved 1300 frames...
# Saved 1400 frames...
# Saved 1500 frames...
# Saved 1600 frames...
# Saved 1700 frames...
# Saved 1800 frames...
# Saved 1900 frames...
# Saved 2000 frames...
# Saved 2100 frames...
# Saved 2200 frames...
# Saved 2300 frames...
# Saved 2400 frames...
# Saved 2500 frames...
# Saved 2600 frames...
# Saved 2700 frames...
# Saved 2800 frames...
# Saved 2900 frames...
# Saved 3000 frames...
# Saved 3100 frames...
# Saved 3200 frames...
# Saved 3300 frames...
# Saved 3400 frames...
# Saved 3500 frames...
# Saved 3600 frames...
# Saved 3700 frames...
# Saved 3800 frames...
# Saved 3900 frames...
# Saved 4000 frames...
# Saved 4100 frames...
# Saved 4200 frames...
# Saved 4300 frames...
# Saved 4400 frames...
# Saved 4500 frames...
# Saved 4600 frames...
# Saved 4700 frames...
# Saved 4800 frames...
# Saved 4900 frames...
# Saved 5000 frames...
# Saved 5100 frames...
# Saved 5200 frames...
# Saved 5300 frames...
# Saved 5400 frames...
# Saved 5500 frames...
# Saved 5600 frames...
# Saved 5700 frames...
# Saved 5800 frames...
# Saved 5900 frames...
# Saved 6000 frames...
# Saved 6100 frames...
# Saved 6200 frames...
# Saved 6300 frames...
# Saved 6400 frames...
# Saved 6500 frames...
# Saved 6600 frames...
# Saved 6700 frames...
# Saved 6800 frames...
# Saved 6900 frames...
# Saved 7000 frames...
# Saved 7100 frames...
# Saved 7200 frames...
# Saved 7300 frames...
# Saved 7400 frames...
# Saved 7500 frames...
# Saved 7600 frames...
# Saved 7700 frames...
# Saved 7800 frames...
# Saved 7900 frames...
# Saved 8000 frames...
# Saved 8100 frames...
# Saved 8200 frames...
# Saved 8300 frames...
# Saved 8400 frames...
# Saved 8500 frames...
# Saved 8600 frames...
# Saved 8700 frames...
# Saved 8800 frames...
# Saved 8900 frames...
# Saved 9000 frames...
# Saved 9100 frames...
# Saved 9200 frames...
# Finished. Scanned 11074 frames, saved 9260 distinct images.
# <class 'pandas.core.frame.DataFrame'>
# Index: 18078 entries, 366926 to 384992
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   video   18078 non-null  object
#  1   frame   18078 non-null  int64
#  2   class   18078 non-null  object
#  3   exist   18078 non-null  bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 582.6+ KB
# Saved 100 frames...
# Saved 200 frames...
# Saved 300 frames...
# Saved 400 frames...
# Saved 500 frames...
# Saved 600 frames...
# Saved 700 frames...
# Saved 800 frames...
# Saved 900 frames...
# Saved 1000 frames...
# Saved 1100 frames...
# Saved 1200 frames...
# Saved 1300 frames...
# Saved 1400 frames...
# Saved 1500 frames...
# Saved 1600 frames...
# Saved 1700 frames...
# Saved 1800 frames...
# Saved 1900 frames...
# Saved 2000 frames...
# Saved 2100 frames...
# Saved 2200 frames...
# Saved 2300 frames...
# Saved 2400 frames...
# Saved 2500 frames...
# Saved 2600 frames...
# Saved 2700 frames...
# Saved 2800 frames...
# Saved 2900 frames...
# Saved 3000 frames...
# Saved 3100 frames...
# Saved 3200 frames...
# Saved 3300 frames...
# Saved 3400 frames...
# Saved 3500 frames...
# Saved 3600 frames...
# Saved 3700 frames...
# Saved 3800 frames...
# Saved 3900 frames...
# Saved 4000 frames...
# Saved 4100 frames...
# Saved 4200 frames...
# Saved 4300 frames...
# Saved 4400 frames...
# Saved 4500 frames...
# Saved 4600 frames...
# Saved 4700 frames...
# Saved 4800 frames...
# Saved 4900 frames...
# Saved 5000 frames...
# Saved 5100 frames...
# Saved 5200 frames...
# Saved 5300 frames...
# Saved 5400 frames...
# Saved 5500 frames...
# Saved 5600 frames...
# Saved 5700 frames...
# Saved 5800 frames...
# Saved 5900 frames...
# Saved 6000 frames...
# Saved 6100 frames...
# Saved 6200 frames...
# Saved 6300 frames...
# Saved 6400 frames...
# Saved 6500 frames...
# Saved 6600 frames...
# Saved 6700 frames...
# Saved 6800 frames...
# Saved 6900 frames...
# Saved 7000 frames...
# Saved 7100 frames...
# Saved 7200 frames...
# Saved 7300 frames...
# Saved 7400 frames...
# Saved 7500 frames...
# Saved 7600 frames...
# Saved 7700 frames...
# Saved 7800 frames...
# Saved 7900 frames...
# Saved 8000 frames...
# Saved 8100 frames...
# Saved 8200 frames...
# Saved 8300 frames...
# Saved 8400 frames...
# Saved 8500 frames...
# Saved 8600 frames...
# Saved 8700 frames...
# Saved 8800 frames...
# Saved 8900 frames...
# Saved 9000 frames...
# Saved 9100 frames...
# Saved 9200 frames...
# Saved 9300 frames...
# Saved 9400 frames...
# Saved 9500 frames...
# Saved 9600 frames...
# Saved 9700 frames...
# Saved 9800 frames...
# Saved 9900 frames...
# Saved 10000 frames...
# Saved 10100 frames...
# Saved 10200 frames...
# Saved 10300 frames...
# Saved 10400 frames...
# Saved 10500 frames...
# Saved 10600 frames...
# Saved 10700 frames...
# Saved 10800 frames...
# Saved 10900 frames...
# Saved 11000 frames...
# Saved 11100 frames...
# Saved 11200 frames...
# Saved 11300 frames...
# Saved 11400 frames...
# Saved 11500 frames...
# Saved 11600 frames...
# Saved 11700 frames...
# Saved 11800 frames...
# Saved 11900 frames...
# Saved 12000 frames...
# Saved 12100 frames...
# Saved 12200 frames...
# Saved 12300 frames...
# Saved 12400 frames...
# Saved 12500 frames...
# Saved 12600 frames...
# Saved 12700 frames...
# Saved 12800 frames...
# Saved 12900 frames...
# Saved 13000 frames...
# Saved 13100 frames...
# Saved 13200 frames...
# Saved 13300 frames...
# Saved 13400 frames...
# Saved 13500 frames...
# Saved 13600 frames...
# Saved 13700 frames...
# Saved 13800 frames...
# Saved 13900 frames...
# Saved 14000 frames...
# Saved 14100 frames...
# Saved 14200 frames...
# Saved 14300 frames...
# Saved 14400 frames...
# Saved 14500 frames...
# Saved 14600 frames...
# Saved 14700 frames...
# Saved 14800 frames...
# Saved 14900 frames...
# Saved 15000 frames...
# Saved 15100 frames...
# Saved 15200 frames...
# Saved 15300 frames...
# Saved 15400 frames...
# Saved 15500 frames...
# Saved 15600 frames...
# Saved 15700 frames...
# Saved 15800 frames...
# Saved 15900 frames...
# Saved 16000 frames...
# Saved 16100 frames...
# Saved 16200 frames...
# Saved 16300 frames...
# Saved 16400 frames...
# Saved 16500 frames...
# Saved 16600 frames...
# Saved 16700 frames...
# Saved 16800 frames...
# Saved 16900 frames...
# Saved 17000 frames...
# Saved 17100 frames...
# Saved 17200 frames...
# Saved 17300 frames...
# Saved 17400 frames...
# Saved 17500 frames...
# Finished. Scanned 18078 frames, saved 17548 distinct images.
# <class 'pandas.core.frame.DataFrame'>
# Index: 8956 entries, 500596 to 509551
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   video   8956 non-null   object
#  1   frame   8956 non-null   int64
#  2   class   8956 non-null   object
#  3   exist   8956 non-null   bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 288.6+ KB
# Saved 100 frames...
# Saved 200 frames...
# Saved 300 frames...
# Saved 400 frames...
# Saved 500 frames...
# Saved 600 frames...
# Saved 700 frames...
# Saved 800 frames...
# Saved 900 frames...
# Saved 1000 frames...
# Saved 1100 frames...
# Saved 1200 frames...
# Saved 1300 frames...
# Saved 1400 frames...
# Saved 1500 frames...
# Saved 1600 frames...
# Saved 1700 frames...
# Saved 1800 frames...
# Saved 1900 frames...
# Saved 2000 frames...
# Saved 2100 frames...
# Saved 2200 frames...
# Saved 2300 frames...
# Saved 2400 frames...
# Saved 2500 frames...
# Saved 2600 frames...
# Saved 2700 frames...
# Saved 2800 frames...
# Saved 2900 frames...
# Saved 3000 frames...
# Saved 3100 frames...
# Saved 3200 frames...
# Saved 3300 frames...
# Saved 3400 frames...
# Saved 3500 frames...
# Saved 3600 frames...
# Saved 3700 frames...
# Saved 3800 frames...
# Saved 3900 frames...
# Saved 4000 frames...
# Saved 4100 frames...
# Saved 4200 frames...
# Saved 4300 frames...
# Saved 4400 frames...
# Saved 4500 frames...
# Saved 4600 frames...
# Saved 4700 frames...
# Saved 4800 frames...
# Saved 4900 frames...
# Saved 5000 frames...
# Saved 5100 frames...
# Saved 5200 frames...
# Saved 5300 frames...
# Saved 5400 frames...
# Saved 5500 frames...
# Saved 5600 frames...
# Saved 5700 frames...
# Saved 5800 frames...
# Saved 5900 frames...
# Saved 6000 frames...
# Saved 6100 frames...
# Saved 6200 frames...
# Saved 6300 frames...
# Saved 6400 frames...
# Saved 6500 frames...
# Saved 6600 frames...
# Saved 6700 frames...
# Saved 6800 frames...
# Saved 6900 frames...
# Saved 7000 frames...
# Saved 7100 frames...
# Saved 7200 frames...
# Saved 7300 frames...
# Saved 7400 frames...
# Saved 7500 frames...
# Saved 7600 frames...
# Saved 7700 frames...
# Saved 7800 frames...
# Saved 7900 frames...
# Saved 8000 frames...
# Saved 8100 frames...
# Saved 8200 frames...
# Saved 8300 frames...
# Saved 8400 frames...
# Saved 8500 frames...
# Saved 8600 frames...
# Finished. Scanned 8956 frames, saved 8697 distinct images.
# <class 'pandas.core.frame.DataFrame'>
# Index: 16641 entries, 557640 to 574280
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   video   16641 non-null  object
#  1   frame   16641 non-null  int64
#  2   class   16641 non-null  object
#  3   exist   16641 non-null  bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 536.3+ KB
# Saved 100 frames...
# Saved 200 frames...
# Saved 300 frames...
# Saved 400 frames...
# Saved 500 frames...
# Saved 600 frames...
# Saved 700 frames...
# Saved 800 frames...
# Saved 900 frames...
# Saved 1000 frames...
# Saved 1100 frames...
# Saved 1200 frames...
# Saved 1300 frames...
# Saved 1400 frames...
# Saved 1500 frames...
# Saved 1600 frames...
# Saved 1700 frames...
# Saved 1800 frames...
# Saved 1900 frames...
# Saved 2000 frames...
# Saved 2100 frames...
# Saved 2200 frames...
# Saved 2300 frames...
# Saved 2400 frames...
# Saved 2500 frames...
# Saved 2600 frames...
# Saved 2700 frames...
# Saved 2800 frames...
# Saved 2900 frames...
# Saved 3000 frames...
# Saved 3100 frames...
# Saved 3200 frames...
# Saved 3300 frames...
# Saved 3400 frames...
# Saved 3500 frames...
# Saved 3600 frames...
# Saved 3700 frames...
# Saved 3800 frames...
# Saved 3900 frames...
# Saved 4000 frames...
# Saved 4100 frames...
# Saved 4200 frames...
# Saved 4300 frames...
# Saved 4400 frames...
# Saved 4500 frames...
# Saved 4600 frames...
# Saved 4700 frames...
# Saved 4800 frames...
# Saved 4900 frames...
# Saved 5000 frames...
# Saved 5100 frames...
# Saved 5200 frames...
# Saved 5300 frames...
# Saved 5400 frames...
# Saved 5500 frames...
# Saved 5600 frames...
# Saved 5700 frames...
# Saved 5800 frames...
# Saved 5900 frames...
# Saved 6000 frames...
# Saved 6100 frames...
# Saved 6200 frames...
# Saved 6300 frames...
# Saved 6400 frames...
# Saved 6500 frames...
# Saved 6600 frames...
# Saved 6700 frames...
# Saved 6800 frames...
# Saved 6900 frames...
# Saved 7000 frames...
# Saved 7100 frames...
# Saved 7200 frames...
# Saved 7300 frames...
# Saved 7400 frames...
# Saved 7500 frames...
# Saved 7600 frames...
# Saved 7700 frames...
# Saved 7800 frames...
# Saved 7900 frames...
# Saved 8000 frames...
# Saved 8100 frames...
# Saved 8200 frames...
# Saved 8300 frames...
# Saved 8400 frames...
# Saved 8500 frames...
# Saved 8600 frames...
# Saved 8700 frames...
# Saved 8800 frames...
# Saved 8900 frames...
# Saved 9000 frames...
# Saved 9100 frames...
# Saved 9200 frames...
# Saved 9300 frames...
# Saved 9400 frames...
# Saved 9500 frames...
# Saved 9600 frames...
# Saved 9700 frames...
# Saved 9800 frames...
# Saved 9900 frames...
# Saved 10000 frames...
# Saved 10100 frames...
# Saved 10200 frames...
# Saved 10300 frames...
# Saved 10400 frames...
# Saved 10500 frames...
# Saved 10600 frames...
# Saved 10700 frames...
# Saved 10800 frames...
# Saved 10900 frames...
# Saved 11000 frames...
# Saved 11100 frames...
# Saved 11200 frames...
# Saved 11300 frames...
# Saved 11400 frames...
# Saved 11500 frames...
# Saved 11600 frames...
# Saved 11700 frames...
# Saved 11800 frames...
# Saved 11900 frames...
# Saved 12000 frames...
# Saved 12100 frames...
# Saved 12200 frames...
# Saved 12300 frames...
# Saved 12400 frames...
# Saved 12500 frames...
# Saved 12600 frames...
# Saved 12700 frames...
# Saved 12800 frames...
# Saved 12900 frames...
# Saved 13000 frames...
# Saved 13100 frames...
# Saved 13200 frames...
# Saved 13300 frames...
# Saved 13400 frames...
# Saved 13500 frames...
# Saved 13600 frames...
# Saved 13700 frames...
# Saved 13800 frames...
# Saved 13900 frames...
# Saved 14000 frames...
# Saved 14100 frames...
# Saved 14200 frames...
# Saved 14300 frames...
# Saved 14400 frames...
# Saved 14500 frames...
# Saved 14600 frames...
# Saved 14700 frames...
# Saved 14800 frames...
# Saved 14900 frames...
# Saved 15000 frames...
# Finished. Scanned 16641 frames, saved 15049 distinct images.
# <class 'pandas.core.frame.DataFrame'>
# Index: 12622 entries, 19201 to 31822
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   video   12622 non-null  object
#  1   frame   12622 non-null  int64
#  2   class   12622 non-null  object
#  3   exist   12622 non-null  bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 406.8+ KB
# Saved 100 frames...
# Saved 200 frames...
# Saved 300 frames...
# Saved 400 frames...
# Saved 500 frames...
# Saved 600 frames...
# Saved 700 frames...
# Saved 800 frames...
# Saved 900 frames...
# Saved 1000 frames...
# Saved 1100 frames...
# Saved 1200 frames...
# Saved 1300 frames...
# Saved 1400 frames...
# Saved 1500 frames...
# Saved 1600 frames...
# Saved 1700 frames...
# Saved 1800 frames...
# Saved 1900 frames...
# Saved 2000 frames...
# Saved 2100 frames...
# Saved 2200 frames...
# Saved 2300 frames...
# Saved 2400 frames...
# Saved 2500 frames...
# Saved 2600 frames...
# Saved 2700 frames...
# Saved 2800 frames...
# Saved 2900 frames...
# Saved 3000 frames...
# Saved 3100 frames...
# Saved 3200 frames...
# Saved 3300 frames...
# Saved 3400 frames...
# Saved 3500 frames...
# Saved 3600 frames...
# Saved 3700 frames...
# Saved 3800 frames...
# Saved 3900 frames...
# Saved 4000 frames...
# Saved 4100 frames...
# Saved 4200 frames...
# Saved 4300 frames...
# Saved 4400 frames...
# Saved 4500 frames...
# Saved 4600 frames...
# Saved 4700 frames...
# Saved 4800 frames...
# Saved 4900 frames...
# Saved 5000 frames...
# Saved 5100 frames...
# Saved 5200 frames...
# Saved 5300 frames...
# Saved 5400 frames...
# Saved 5500 frames...
# Saved 5600 frames...
# Saved 5700 frames...
# Saved 5800 frames...
# Saved 5900 frames...
# Saved 6000 frames...
# Saved 6100 frames...
# Saved 6200 frames...
# Saved 6300 frames...
# Saved 6400 frames...
# Saved 6500 frames...
# Saved 6600 frames...
# Saved 6700 frames...
# Saved 6800 frames...
# Saved 6900 frames...
# Saved 7000 frames...
# Saved 7100 frames...
# Saved 7200 frames...
# Saved 7300 frames...
# Saved 7400 frames...
# Saved 7500 frames...
# Saved 7600 frames...
# Saved 7700 frames...
# Saved 7800 frames...
# Saved 7900 frames...
# Saved 8000 frames...
# Saved 8100 frames...
# Saved 8200 frames...
# Saved 8300 frames...
# Saved 8400 frames...
# Saved 8500 frames...
# Saved 8600 frames...
# Saved 8700 frames...
# Saved 8800 frames...
# Saved 8900 frames...
# Saved 9000 frames...
# Saved 9100 frames...
# Saved 9200 frames...
# Saved 9300 frames...
# Saved 9400 frames...
# Saved 9500 frames...
# Saved 9600 frames...
# Saved 9700 frames...
# Saved 9800 frames...
# Saved 9900 frames...
# Saved 10000 frames...
# Saved 10100 frames...
# Saved 10200 frames...
# Saved 10300 frames...
# Saved 10400 frames...
# Saved 10500 frames...
# Saved 10600 frames...
# Saved 10700 frames...
# Saved 10800 frames...
# Saved 10900 frames...
# Saved 11000 frames...
# Saved 11100 frames...
# Saved 11200 frames...
# Saved 11300 frames...
# Saved 11400 frames...
# Saved 11500 frames...
# Saved 11600 frames...
# Saved 11700 frames...
# Saved 11800 frames...
# Saved 11900 frames...
# Saved 12000 frames...
# Saved 12100 frames...
# Saved 12200 frames...
# Saved 12300 frames...
# Finished. Scanned 12622 frames, saved 12335 distinct images.
# <class 'pandas.core.frame.DataFrame'>
# Index: 17616 entries, 815023 to 832638
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   video   17616 non-null  object
#  1   frame   17616 non-null  int64
#  2   class   17616 non-null  object
#  3   exist   17616 non-null  bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 567.7+ KB
# Saved 100 frames...
# Saved 200 frames...
# Saved 300 frames...
# Saved 400 frames...
# Saved 500 frames...
# Saved 600 frames...
# Saved 700 frames...
# Saved 800 frames...
# Saved 900 frames...
# Saved 1000 frames...
# Saved 1100 frames...
# Saved 1200 frames...
# Saved 1300 frames...
# Saved 1400 frames...
# Saved 1500 frames...
# Saved 1600 frames...
# Saved 1700 frames...
# Saved 1800 frames...
# Saved 1900 frames...
# Saved 2000 frames...
# Saved 2100 frames...
# Saved 2200 frames...
# Saved 2300 frames...
# Saved 2400 frames...
# Saved 2500 frames...
# Saved 2600 frames...
# Saved 2700 frames...
# Saved 2800 frames...
# Saved 2900 frames...
# Saved 3000 frames...
# Saved 3100 frames...
# Saved 3200 frames...
# Saved 3300 frames...
# Saved 3400 frames...
# Saved 3500 frames...
# Saved 3600 frames...
# Saved 3700 frames...
# Saved 3800 frames...
# Saved 3900 frames...
# Saved 4000 frames...
# Saved 4100 frames...
# Saved 4200 frames...
# Saved 4300 frames...
# Saved 4400 frames...
# Saved 4500 frames...
# Saved 4600 frames...
# Saved 4700 frames...
# Saved 4800 frames...
# Saved 4900 frames...
# Saved 5000 frames...
# Saved 5100 frames...
# Saved 5200 frames...
# Saved 5300 frames...
# Saved 5400 frames...
# Saved 5500 frames...
# Saved 5600 frames...
# Saved 5700 frames...
# Saved 5800 frames...
# Saved 5900 frames...
# Saved 6000 frames...
# Saved 6100 frames...
# Saved 6200 frames...
# Saved 6300 frames...
# Saved 6400 frames...
# Saved 6500 frames...
# Saved 6600 frames...
# Saved 6700 frames...
# Saved 6800 frames...
# Saved 6900 frames...
# Saved 7000 frames...
# Saved 7100 frames...
# Saved 7200 frames...
# Saved 7300 frames...
# Saved 7400 frames...
# Saved 7500 frames...
# Saved 7600 frames...
# Saved 7700 frames...
# Saved 7800 frames...
# Saved 7900 frames...
# Saved 8000 frames...
# Saved 8100 frames...
# Saved 8200 frames...
# Saved 8300 frames...
# Saved 8400 frames...
# Saved 8500 frames...
# Saved 8600 frames...
# Saved 8700 frames...
# Saved 8800 frames...
# Saved 8900 frames...
# Saved 9000 frames...
# Saved 9100 frames...
# Saved 9200 frames...
# Saved 9300 frames...
# Saved 9400 frames...
# Saved 9500 frames...
# Saved 9600 frames...
# Saved 9700 frames...
# Saved 9800 frames...
# Saved 9900 frames...
# Saved 10000 frames...
# Saved 10100 frames...
# Saved 10200 frames...
# Saved 10300 frames...
# Saved 10400 frames...
# Saved 10500 frames...
# Saved 10600 frames...
# Saved 10700 frames...
# Saved 10800 frames...
# Saved 10900 frames...
# Saved 11000 frames...
# Saved 11100 frames...
# Saved 11200 frames...
# Saved 11300 frames...
# Saved 11400 frames...
# Saved 11500 frames...
# Saved 11600 frames...
# Saved 11700 frames...
# Saved 11800 frames...
# Saved 11900 frames...
# Saved 12000 frames...
# Saved 12100 frames...
# Saved 12200 frames...
# Saved 12300 frames...
# Saved 12400 frames...
# Saved 12500 frames...
# Saved 12600 frames...
# Saved 12700 frames...
# Saved 12800 frames...
# Saved 12900 frames...
# Saved 13000 frames...
# Saved 13100 frames...
# Saved 13200 frames...
# Saved 13300 frames...
# Saved 13400 frames...
# Saved 13500 frames...
# Saved 13600 frames...
# Saved 13700 frames...
# Saved 13800 frames...
# Saved 13900 frames...
# Saved 14000 frames...
# Saved 14100 frames...
# Saved 14200 frames...
# Saved 14300 frames...
# Saved 14400 frames...
# Saved 14500 frames...
# Saved 14600 frames...
# Saved 14700 frames...
# Saved 14800 frames...
# Saved 14900 frames...
# Saved 15000 frames...
# Saved 15100 frames...
# Saved 15200 frames...
# Saved 15300 frames...
# Saved 15400 frames...
# Saved 15500 frames...
# Saved 15600 frames...
# Saved 15700 frames...
# Saved 15800 frames...
# Saved 15900 frames...
# Saved 16000 frames...
# Saved 16100 frames...
# Saved 16200 frames...
# Finished. Scanned 17616 frames, saved 16217 distinct images.
# <class 'pandas.core.frame.DataFrame'>
# Index: 9152 entries, 737789 to 746940
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   video   9152 non-null   object
#  1   frame   9152 non-null   int64
#  2   class   9152 non-null   object
#  3   exist   9152 non-null   bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 294.9+ KB
# Saved 100 frames...
# Saved 200 frames...
# Saved 300 frames...
# Saved 400 frames...
# Saved 500 frames...
# Saved 600 frames...
# Saved 700 frames...
# Saved 800 frames...
# Saved 900 frames...
# Saved 1000 frames...
# Saved 1100 frames...
# Saved 1200 frames...
# Saved 1300 frames...
# Saved 1400 frames...
# Saved 1500 frames...
# Saved 1600 frames...
# Saved 1700 frames...
# Saved 1800 frames...
# Saved 1900 frames...
# Saved 2000 frames...
# Saved 2100 frames...
# Saved 2200 frames...
# Saved 2300 frames...
# Saved 2400 frames...
# Saved 2500 frames...
# Saved 2600 frames...
# Saved 2700 frames...
# Saved 2800 frames...
# Saved 2900 frames...
# Saved 3000 frames...
# Saved 3100 frames...
# Saved 3200 frames...
# Saved 3300 frames...
# Saved 3400 frames...
# Saved 3500 frames...
# Saved 3600 frames...
# Saved 3700 frames...
# Saved 3800 frames...
# Saved 3900 frames...
# Saved 4000 frames...
# Saved 4100 frames...
# Saved 4200 frames...
# Saved 4300 frames...
# Saved 4400 frames...
# Saved 4500 frames...
# Saved 4600 frames...
# Saved 4700 frames...
# Saved 4800 frames...
# Saved 4900 frames...
# Saved 5000 frames...
# Saved 5100 frames...
# Saved 5200 frames...
# Saved 5300 frames...
# Saved 5400 frames...
# Saved 5500 frames...
# Saved 5600 frames...
# Saved 5700 frames...
# Saved 5800 frames...
# Saved 5900 frames...
# Saved 6000 frames...
# Saved 6100 frames...
# Saved 6200 frames...
# Saved 6300 frames...
# Saved 6400 frames...
# Saved 6500 frames...
# Saved 6600 frames...
# Saved 6700 frames...
# Saved 6800 frames...
# Saved 6900 frames...
# Saved 7000 frames...
# Saved 7100 frames...
# Saved 7200 frames...
# Saved 7300 frames...
# Saved 7400 frames...
# Saved 7500 frames...
# Saved 7600 frames...
# Saved 7700 frames...
# Saved 7800 frames...
# Saved 7900 frames...
# Saved 8000 frames...
# Saved 8100 frames...
# Saved 8200 frames...
# Saved 8300 frames...
# Saved 8400 frames...
# Saved 8500 frames...
# Saved 8600 frames...
# Saved 8700 frames...
# Saved 8800 frames...
# Saved 8900 frames...
# Finished. Scanned 9152 frames, saved 8917 distinct images.
# <class 'pandas.core.frame.DataFrame'>
# Index: 19201 entries, 0 to 19200
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   video   19201 non-null  object
#  1   frame   19201 non-null  int64
#  2   class   19201 non-null  object
#  3   exist   19201 non-null  bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 618.8+ KB
# Saved 100 frames...
# Saved 200 frames...
# Saved 300 frames...
# Saved 400 frames...
# Saved 500 frames...
# Saved 600 frames...
# Saved 700 frames...
# Saved 800 frames...
# Saved 900 frames...
# Saved 1000 frames...
# Saved 1100 frames...
# Saved 1200 frames...
# Saved 1300 frames...
# Saved 1400 frames...
# Saved 1500 frames...
# Saved 1600 frames...
# Saved 1700 frames...
# Saved 1800 frames...
# Saved 1900 frames...
# Saved 2000 frames...
# Saved 2100 frames...
# Saved 2200 frames...
# Saved 2300 frames...
# Saved 2400 frames...
# Saved 2500 frames...
# Saved 2600 frames...
# Saved 2700 frames...
# Saved 2800 frames...
# Saved 2900 frames...
# Saved 3000 frames...
# Saved 3100 frames...
# Saved 3200 frames...
# Saved 3300 frames...
# Saved 3400 frames...
# Saved 3500 frames...
# Saved 3600 frames...
# Saved 3700 frames...
# Saved 3800 frames...
# Saved 3900 frames...
# Saved 4000 frames...
# Saved 4100 frames...
# Saved 4200 frames...
# Saved 4300 frames...
# Saved 4400 frames...
# Saved 4500 frames...
# Saved 4600 frames...
# Saved 4700 frames...
# Saved 4800 frames...
# Saved 4900 frames...
# Saved 5000 frames...
# Saved 5100 frames...
# Saved 5200 frames...
# Saved 5300 frames...
# Saved 5400 frames...
# Saved 5500 frames...
# Saved 5600 frames...
# Saved 5700 frames...
# Saved 5800 frames...
# Saved 5900 frames...
# Saved 6000 frames...
# Saved 6100 frames...
# Saved 6200 frames...
# Saved 6300 frames...
# Saved 6400 frames...
# Saved 6500 frames...
# Saved 6600 frames...
# Saved 6700 frames...
# Saved 6800 frames...
# Saved 6900 frames...
# Saved 7000 frames...
# Saved 7100 frames...
# Saved 7200 frames...
# Saved 7300 frames...
# Saved 7400 frames...
# Saved 7500 frames...
# Saved 7600 frames...
# Saved 7700 frames...
# Saved 7800 frames...
# Saved 7900 frames...
# Saved 8000 frames...
# Saved 8100 frames...
# Saved 8200 frames...
# Saved 8300 frames...
# Saved 8400 frames...
# Saved 8500 frames...
# Saved 8600 frames...
# Saved 8700 frames...
# Saved 8800 frames...
# Saved 8900 frames...
# Saved 9000 frames...
# Saved 9100 frames...
# Saved 9200 frames...
# Saved 9300 frames...
# Saved 9400 frames...
# Saved 9500 frames...
# Saved 9600 frames...
# Saved 9700 frames...
# Saved 9800 frames...
# Saved 9900 frames...
# Saved 10000 frames...
# Saved 10100 frames...
# Saved 10200 frames...
# Saved 10300 frames...
# Saved 10400 frames...
# Saved 10500 frames...
# Saved 10600 frames...
# Saved 10700 frames...
# Saved 10800 frames...
# Saved 10900 frames...
# Saved 11000 frames...
# Saved 11100 frames...
# Saved 11200 frames...
# Saved 11300 frames...
# Saved 11400 frames...
# Saved 11500 frames...
# Saved 11600 frames...
# Saved 11700 frames...
# Saved 11800 frames...
# Saved 11900 frames...
# Saved 12000 frames...
# Saved 12100 frames...
# Saved 12200 frames...
# Saved 12300 frames...
# Saved 12400 frames...
# Saved 12500 frames...
# Saved 12600 frames...
# Saved 12700 frames...
# Saved 12800 frames...
# Saved 12900 frames...
# Saved 13000 frames...
# Saved 13100 frames...
# Saved 13200 frames...
# Saved 13300 frames...
# Saved 13400 frames...
# Saved 13500 frames...
# Saved 13600 frames...
# Saved 13700 frames...
# Saved 13800 frames...
# Saved 13900 frames...
# Saved 14000 frames...
# Saved 14100 frames...
# Saved 14200 frames...
# Saved 14300 frames...
# Saved 14400 frames...
# Saved 14500 frames...
# Saved 14600 frames...
# Saved 14700 frames...
# Saved 14800 frames...
# Saved 14900 frames...
# Saved 15000 frames...
# Saved 15100 frames...
# Saved 15200 frames...
# Saved 15300 frames...
# Saved 15400 frames...
# Saved 15500 frames...
# Saved 15600 frames...
# Saved 15700 frames...
# Saved 15800 frames...
# Saved 15900 frames...
# Saved 16000 frames...
# Saved 16100 frames...
# Saved 16200 frames...
# Saved 16300 frames...
# Saved 16400 frames...
# Saved 16500 frames...
# Saved 16600 frames...
# Saved 16700 frames...
# Saved 16800 frames...
# Saved 16900 frames...
# Saved 17000 frames...
# Saved 17100 frames...
# Saved 17200 frames...
# Saved 17300 frames...
# Saved 17400 frames...
# Saved 17500 frames...
# Saved 17600 frames...
# Saved 17700 frames...
# Saved 17800 frames...
# Saved 17900 frames...
# Saved 18000 frames...
# Saved 18100 frames...
# Saved 18200 frames...
# Saved 18300 frames...
# Saved 18400 frames...
# Finished. Scanned 19201 frames, saved 18486 distinct images.
# <class 'pandas.core.frame.DataFrame'>
# Index: 12198 entries, 901935 to 914132
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   video   12198 non-null  object
#  1   frame   12198 non-null  int64
#  2   class   12198 non-null  object
#  3   exist   12198 non-null  bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 393.1+ KB
# Saved 100 frames...
# Saved 200 frames...
# Saved 300 frames...
# Saved 400 frames...
# Saved 500 frames...
# Saved 600 frames...
# Saved 700 frames...
# Saved 800 frames...
# Saved 900 frames...
# Saved 1000 frames...
# Saved 1100 frames...
# Saved 1200 frames...
# Saved 1300 frames...
# Saved 1400 frames...
# Saved 1500 frames...
# Saved 1600 frames...
# Saved 1700 frames...
# Saved 1800 frames...
# Saved 1900 frames...
# Saved 2000 frames...
# Saved 2100 frames...
# Saved 2200 frames...
# Saved 2300 frames...
# Saved 2400 frames...
# Saved 2500 frames...
# Saved 2600 frames...
# Saved 2700 frames...
# Saved 2800 frames...
# Saved 2900 frames...
# Saved 3000 frames...
# Saved 3100 frames...
# Saved 3200 frames...
# Saved 3300 frames...
# Saved 3400 frames...
# Saved 3500 frames...
# Saved 3600 frames...
# Saved 3700 frames...
# Saved 3800 frames...
# Saved 3900 frames...
# Saved 4000 frames...
# Saved 4100 frames...
# Saved 4200 frames...
# Saved 4300 frames...
# Saved 4400 frames...
# Saved 4500 frames...
# Saved 4600 frames...
# Saved 4700 frames...
# Saved 4800 frames...
# Saved 4900 frames...
# Saved 5000 frames...
# Saved 5100 frames...
# Saved 5200 frames...
# Saved 5300 frames...
# Saved 5400 frames...
# Saved 5500 frames...
# Saved 5600 frames...
# Saved 5700 frames...
# Saved 5800 frames...
# Saved 5900 frames...
# Saved 6000 frames...
# Saved 6100 frames...
# Saved 6200 frames...
# Saved 6300 frames...
# Saved 6400 frames...
# Saved 6500 frames...
# Saved 6600 frames...
# Saved 6700 frames...
# Saved 6800 frames...
# Saved 6900 frames...
# Saved 7000 frames...
# Saved 7100 frames...
# Saved 7200 frames...
# Saved 7300 frames...
# Saved 7400 frames...
# Saved 7500 frames...
# Saved 7600 frames...
# Saved 7700 frames...
# Saved 7800 frames...
# Saved 7900 frames...
# Saved 8000 frames...
# Saved 8100 frames...
# Saved 8200 frames...
# Saved 8300 frames...
# Saved 8400 frames...
# Saved 8500 frames...
# Saved 8600 frames...
# Saved 8700 frames...
# Saved 8800 frames...
# Saved 8900 frames...
# Saved 9000 frames...
# Saved 9100 frames...
# Saved 9200 frames...
# Saved 9300 frames...
# Saved 9400 frames...
# Saved 9500 frames...
# Saved 9600 frames...
# Saved 9700 frames...
# Saved 9800 frames...
# Saved 9900 frames...
# Saved 10000 frames...
# Saved 10100 frames...
# Saved 10200 frames...
# Saved 10300 frames...
# Saved 10400 frames...
# Saved 10500 frames...
# Saved 10600 frames...
# Saved 10700 frames...
# Saved 10800 frames...
# Saved 10900 frames...
# Saved 11000 frames...
# Saved 11100 frames...
# Saved 11200 frames...
# Saved 11300 frames...
# Finished. Scanned 12198 frames, saved 11364 distinct images.
# <class 'pandas.core.frame.DataFrame'>
# Index: 17988 entries, 719801 to 737788
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   video   17988 non-null  object
#  1   frame   17988 non-null  int64
#  2   class   17988 non-null  object
#  3   exist   17988 non-null  bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 579.7+ KB
# Saved 100 frames...
# Saved 200 frames...
# Saved 300 frames...
# Saved 400 frames...
# Saved 500 frames...
# Saved 600 frames...
# Saved 700 frames...
# Saved 800 frames...
# Saved 900 frames...
# Saved 1000 frames...
# Saved 1100 frames...
# Saved 1200 frames...
# Saved 1300 frames...
# Saved 1400 frames...
# Saved 1500 frames...
# Saved 1600 frames...
# Saved 1700 frames...
# Saved 1800 frames...
# Saved 1900 frames...
# Saved 2000 frames...
# Saved 2100 frames...
# Saved 2200 frames...
# Saved 2300 frames...
# Saved 2400 frames...
# Saved 2500 frames...
# Saved 2600 frames...
# Saved 2700 frames...
# Saved 2800 frames...
# Saved 2900 frames...
# Saved 3000 frames...
# Saved 3100 frames...
# Saved 3200 frames...
# Saved 3300 frames...
# Saved 3400 frames...
# Saved 3500 frames...
# Saved 3600 frames...
# Saved 3700 frames...
# Saved 3800 frames...
# Saved 3900 frames...
# Saved 4000 frames...
# Saved 4100 frames...
# Saved 4200 frames...
# Saved 4300 frames...
# Saved 4400 frames...
# Saved 4500 frames...
# Saved 4600 frames...
# Saved 4700 frames...
# Saved 4800 frames...
# Saved 4900 frames...
# Saved 5000 frames...
# Saved 5100 frames...
# Saved 5200 frames...
# Saved 5300 frames...
# Saved 5400 frames...
# Saved 5500 frames...
# Saved 5600 frames...
# Saved 5700 frames...
# Saved 5800 frames...
# Saved 5900 frames...
# Saved 6000 frames...
# Saved 6100 frames...
# Saved 6200 frames...
# Saved 6300 frames...
# Saved 6400 frames...
# Saved 6500 frames...
# Saved 6600 frames...
# Saved 6700 frames...
# Saved 6800 frames...
# Saved 6900 frames...
# Saved 7000 frames...
# Saved 7100 frames...
# Saved 7200 frames...
# Saved 7300 frames...
# Saved 7400 frames...
# Saved 7500 frames...
# Saved 7600 frames...
# Saved 7700 frames...
# Saved 7800 frames...
# Saved 7900 frames...
# Saved 8000 frames...
# Saved 8100 frames...
# Saved 8200 frames...
# Saved 8300 frames...
# Saved 8400 frames...
# Saved 8500 frames...
# Saved 8600 frames...
# Saved 8700 frames...
# Saved 8800 frames...
# Saved 8900 frames...
# Saved 9000 frames...
# Saved 9100 frames...
# Saved 9200 frames...
# Saved 9300 frames...
# Saved 9400 frames...
# Saved 9500 frames...
# Saved 9600 frames...
# Saved 9700 frames...
# Saved 9800 frames...
# Saved 9900 frames...
# Saved 10000 frames...
# Saved 10100 frames...
# Saved 10200 frames...
# Saved 10300 frames...
# Saved 10400 frames...
# Saved 10500 frames...
# Saved 10600 frames...
# Saved 10700 frames...
# Saved 10800 frames...
# Saved 10900 frames...
# Saved 11000 frames...
# Saved 11100 frames...
# Saved 11200 frames...
# Saved 11300 frames...
# Saved 11400 frames...
# Saved 11500 frames...
# Saved 11600 frames...
# Saved 11700 frames...
# Saved 11800 frames...
# Saved 11900 frames...
# Saved 12000 frames...
# Saved 12100 frames...
# Saved 12200 frames...
# Saved 12300 frames...
# Saved 12400 frames...
# Saved 12500 frames...
# Saved 12600 frames...
# Saved 12700 frames...
# Saved 12800 frames...
# Saved 12900 frames...
# Saved 13000 frames...
# Saved 13100 frames...
# Saved 13200 frames...
# Saved 13300 frames...
# Saved 13400 frames...
# Saved 13500 frames...
# Saved 13600 frames...
# Saved 13700 frames...
# Saved 13800 frames...
# Saved 13900 frames...
# Saved 14000 frames...
# Saved 14100 frames...
# Saved 14200 frames...
# Saved 14300 frames...
# Saved 14400 frames...
# Saved 14500 frames...
# Saved 14600 frames...
# Saved 14700 frames...
# Saved 14800 frames...
# Saved 14900 frames...
# Saved 15000 frames...
# Saved 15100 frames...
# Saved 15200 frames...
# Saved 15300 frames...
# Saved 15400 frames...
# Saved 15500 frames...
# Saved 15600 frames...
# Saved 15700 frames...
# Saved 15800 frames...
# Saved 15900 frames...
# Saved 16000 frames...
# Saved 16100 frames...
# Saved 16200 frames...
# Saved 16300 frames...
# Saved 16400 frames...
# Saved 16500 frames...
# Saved 16600 frames...
# Saved 16700 frames...
# Saved 16800 frames...
# Saved 16900 frames...
# Saved 17000 frames...
# Finished. Scanned 17988 frames, saved 17087 distinct images.
# <class 'pandas.core.frame.DataFrame'>
# Index: 9204 entries, 548436 to 557639
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   video   9204 non-null   object
#  1   frame   9204 non-null   int64
#  2   class   9204 non-null   object
#  3   exist   9204 non-null   bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 296.6+ KB
# Saved 100 frames...
# Saved 200 frames...
# Saved 300 frames...
# Saved 400 frames...
# Saved 500 frames...
# Saved 600 frames...
# Saved 700 frames...
# Saved 800 frames...
# Saved 900 frames...
# Saved 1000 frames...
# Saved 1100 frames...
# Saved 1200 frames...
# Saved 1300 frames...
# Saved 1400 frames...
# Saved 1500 frames...
# Saved 1600 frames...
# Saved 1700 frames...
# Saved 1800 frames...
# Saved 1900 frames...
# Saved 2000 frames...
# Saved 2100 frames...
# Saved 2200 frames...
# Saved 2300 frames...
# Saved 2400 frames...
# Saved 2500 frames...
# Saved 2600 frames...
# Saved 2700 frames...
# Saved 2800 frames...
# Saved 2900 frames...
# Saved 3000 frames...
# Saved 3100 frames...
# Saved 3200 frames...
# Saved 3300 frames...
# Saved 3400 frames...
# Saved 3500 frames...
# Saved 3600 frames...
# Saved 3700 frames...
# Saved 3800 frames...
# Saved 3900 frames...
# Saved 4000 frames...
# Saved 4100 frames...
# Saved 4200 frames...
# Saved 4300 frames...
# Saved 4400 frames...
# Saved 4500 frames...
# Saved 4600 frames...
# Saved 4700 frames...
# Saved 4800 frames...
# Saved 4900 frames...
# Saved 5000 frames...
# Saved 5100 frames...
# Saved 5200 frames...
# Saved 5300 frames...
# Saved 5400 frames...
# Saved 5500 frames...
# Saved 5600 frames...
# Saved 5700 frames...
# Saved 5800 frames...
# Saved 5900 frames...
# Saved 6000 frames...
# Saved 6100 frames...
# Saved 6200 frames...
# Saved 6300 frames...
# Saved 6400 frames...
# Saved 6500 frames...
# Saved 6600 frames...
# Saved 6700 frames...
# Saved 6800 frames...
# Saved 6900 frames...
# Saved 7000 frames...
# Saved 7100 frames...
# Saved 7200 frames...
# Saved 7300 frames...
# Saved 7400 frames...
# Saved 7500 frames...
# Saved 7600 frames...
# Saved 7700 frames...
# Saved 7800 frames...
# Saved 7900 frames...
# Saved 8000 frames...
# Saved 8100 frames...
# Saved 8200 frames...
# Saved 8300 frames...
# Saved 8400 frames...
# Saved 8500 frames...
# Saved 8600 frames...
# Saved 8700 frames...
# Saved 8800 frames...
# Finished. Scanned 9204 frames, saved 8892 distinct images.
# <class 'pandas.core.frame.DataFrame'>
# Index: 15447 entries, 886488 to 901934
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   video   15447 non-null  object
#  1   frame   15447 non-null  int64
#  2   class   15447 non-null  object
#  3   exist   15447 non-null  bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 497.8+ KB
# Saved 100 frames...
# Saved 200 frames...
# Saved 300 frames...
# Saved 400 frames...
# Saved 500 frames...
# Saved 600 frames...
# Saved 700 frames...
# Saved 800 frames...
# Saved 900 frames...
# Saved 1000 frames...
# Saved 1100 frames...
# Saved 1200 frames...
# Saved 1300 frames...
# Saved 1400 frames...
# Saved 1500 frames...
# Saved 1600 frames...
# Saved 1700 frames...
# Saved 1800 frames...
# Saved 1900 frames...
# Saved 2000 frames...
# Saved 2100 frames...
# Saved 2200 frames...
# Saved 2300 frames...
# Saved 2400 frames...
# Saved 2500 frames...
# Saved 2600 frames...
# Saved 2700 frames...
# Saved 2800 frames...
# Saved 2900 frames...
# Saved 3000 frames...
# Saved 3100 frames...
# Saved 3200 frames...
# Saved 3300 frames...
# Saved 3400 frames...
# Saved 3500 frames...
# Saved 3600 frames...
# Saved 3700 frames...
# Saved 3800 frames...
# Saved 3900 frames...
# Saved 4000 frames...
# Saved 4100 frames...
# Saved 4200 frames...
# Saved 4300 frames...
# Saved 4400 frames...
# Saved 4500 frames...
# Saved 4600 frames...
# Saved 4700 frames...
# Saved 4800 frames...
# Saved 4900 frames...
# Saved 5000 frames...
# Saved 5100 frames...
# Saved 5200 frames...
# Saved 5300 frames...
# Saved 5400 frames...
# Saved 5500 frames...
# Saved 5600 frames...
# Saved 5700 frames...
# Saved 5800 frames...
# Saved 5900 frames...
# Saved 6000 frames...
# Saved 6100 frames...
# Saved 6200 frames...
# Saved 6300 frames...
# Saved 6400 frames...
# Saved 6500 frames...
# Saved 6600 frames...
# Saved 6700 frames...
# Saved 6800 frames...
# Saved 6900 frames...
# Saved 7000 frames...
# Saved 7100 frames...
# Saved 7200 frames...
# Saved 7300 frames...
# Saved 7400 frames...
# Saved 7500 frames...
# Saved 7600 frames...
# Saved 7700 frames...
# Saved 7800 frames...
# Saved 7900 frames...
# Saved 8000 frames...
# Saved 8100 frames...
# Saved 8200 frames...
# Saved 8300 frames...
# Saved 8400 frames...
# Saved 8500 frames...
# Saved 8600 frames...
# Saved 8700 frames...
# Saved 8800 frames...
# Saved 8900 frames...
# Saved 9000 frames...
# Saved 9100 frames...
# Saved 9200 frames...
# Saved 9300 frames...
# Saved 9400 frames...
# Saved 9500 frames...
# Saved 9600 frames...
# Saved 9700 frames...
# Saved 9800 frames...
# Saved 9900 frames...
# Saved 10000 frames...
# Saved 10100 frames...
# Saved 10200 frames...
# Saved 10300 frames...
# Saved 10400 frames...
# Saved 10500 frames...
# Saved 10600 frames...
# Saved 10700 frames...
# Saved 10800 frames...
# Saved 10900 frames...
# Saved 11000 frames...
# Saved 11100 frames...
# Saved 11200 frames...
# Saved 11300 frames...
# Saved 11400 frames...
# Saved 11500 frames...
# Saved 11600 frames...
# Saved 11700 frames...
# Saved 11800 frames...
# Saved 11900 frames...
# Saved 12000 frames...
# Saved 12100 frames...
# Saved 12200 frames...
# Saved 12300 frames...
# Saved 12400 frames...
# Saved 12500 frames...
# Saved 12600 frames...
# Saved 12700 frames...
# Saved 12800 frames...
# Saved 12900 frames...
# Saved 13000 frames...
# Saved 13100 frames...
# Saved 13200 frames...
# Saved 13300 frames...
# Saved 13400 frames...
# Saved 13500 frames...
# Saved 13600 frames...
# Saved 13700 frames...
# Saved 13800 frames...
# Saved 13900 frames...
# Saved 14000 frames...
# Saved 14100 frames...
# Saved 14200 frames...
# Saved 14300 frames...
# Saved 14400 frames...
# Saved 14500 frames...
# Saved 14600 frames...
# Saved 14700 frames...
# Finished. Scanned 15447 frames, saved 14717 distinct images.
# <class 'pandas.core.frame.DataFrame'>
# Index: 9778 entries, 200642 to 210419
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   video   9778 non-null   object
#  1   frame   9778 non-null   int64
#  2   class   9778 non-null   object
#  3   exist   9778 non-null   bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 315.1+ KB
# Saved 100 frames...
# Saved 200 frames...
# Saved 300 frames...
# Saved 400 frames...
# Saved 500 frames...
# Saved 600 frames...
# Saved 700 frames...
# Saved 800 frames...
# Saved 900 frames...
# Saved 1000 frames...
# Saved 1100 frames...
# Saved 1200 frames...
# Saved 1300 frames...
# Saved 1400 frames...
# Saved 1500 frames...
# Saved 1600 frames...
# Saved 1700 frames...
# Saved 1800 frames...
# Saved 1900 frames...
# Saved 2000 frames...
# Saved 2100 frames...
# Saved 2200 frames...
# Saved 2300 frames...
# Saved 2400 frames...
# Saved 2500 frames...
# Saved 2600 frames...
# Saved 2700 frames...
# Saved 2800 frames...
# Saved 2900 frames...
# Saved 3000 frames...
# Saved 3100 frames...
# Saved 3200 frames...
# Saved 3300 frames...
# Saved 3400 frames...
# Saved 3500 frames...
# Saved 3600 frames...
# Saved 3700 frames...
# Saved 3800 frames...
# Saved 3900 frames...
# Saved 4000 frames...
# Saved 4100 frames...
# Saved 4200 frames...
# Saved 4300 frames...
# Saved 4400 frames...
# Saved 4500 frames...
# Saved 4600 frames...
# Saved 4700 frames...
# Saved 4800 frames...
# Saved 4900 frames...
# Saved 5000 frames...
# Saved 5100 frames...
# Saved 5200 frames...
# Saved 5300 frames...
# Saved 5400 frames...
# Saved 5500 frames...
# Saved 5600 frames...
# Saved 5700 frames...
# Saved 5800 frames...
# Saved 5900 frames...
# Saved 6000 frames...
# Saved 6100 frames...
# Saved 6200 frames...
# Saved 6300 frames...
# Saved 6400 frames...
# Saved 6500 frames...
# Saved 6600 frames...
# Saved 6700 frames...
# Saved 6800 frames...
# Saved 6900 frames...
# Saved 7000 frames...
# Saved 7100 frames...
# Saved 7200 frames...
# Saved 7300 frames...
# Saved 7400 frames...
# Saved 7500 frames...
# Saved 7600 frames...
# Saved 7700 frames...
# Saved 7800 frames...
# Saved 7900 frames...
# Saved 8000 frames...
# Saved 8100 frames...
# Saved 8200 frames...
# Saved 8300 frames...
# Saved 8400 frames...
# Saved 8500 frames...
# Saved 8600 frames...
# Saved 8700 frames...
# Saved 8800 frames...
# Saved 8900 frames...
# Saved 9000 frames...
# Saved 9100 frames...
# Saved 9200 frames...
# Saved 9300 frames...
# Saved 9400 frames...
# Saved 9500 frames...
# Saved 9600 frames...
# Finished. Scanned 9778 frames, saved 9688 distinct images.
# <class 'pandas.core.frame.DataFrame'>
# Index: 15960 entries, 278108 to 294067
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   video   15960 non-null  object
#  1   frame   15960 non-null  int64
#  2   class   15960 non-null  object
#  3   exist   15960 non-null  bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 514.3+ KB
# Saved 100 frames...
# Saved 200 frames...
# Saved 300 frames...
# Saved 400 frames...
# Saved 500 frames...
# Saved 600 frames...
# Saved 700 frames...
# Saved 800 frames...
# Saved 900 frames...
# Saved 1000 frames...
# Saved 1100 frames...
# Saved 1200 frames...
# Saved 1300 frames...
# Saved 1400 frames...
# Saved 1500 frames...
# Saved 1600 frames...
# Saved 1700 frames...
# Saved 1800 frames...
# Saved 1900 frames...
# Saved 2000 frames...
# Saved 2100 frames...
# Saved 2200 frames...
# Saved 2300 frames...
# Saved 2400 frames...
# Saved 2500 frames...
# Saved 2600 frames...
# Saved 2700 frames...
# Saved 2800 frames...
# Saved 2900 frames...
# Saved 3000 frames...
# Saved 3100 frames...
# Saved 3200 frames...
# Saved 3300 frames...
# Saved 3400 frames...
# Saved 3500 frames...
# Saved 3600 frames...
# Saved 3700 frames...
# Saved 3800 frames...
# Saved 3900 frames...
# Saved 4000 frames...
# Saved 4100 frames...
# Saved 4200 frames...
# Saved 4300 frames...
# Saved 4400 frames...
# Saved 4500 frames...
# Saved 4600 frames...
# Saved 4700 frames...
# Saved 4800 frames...
# Saved 4900 frames...
# Saved 5000 frames...
# Saved 5100 frames...
# Saved 5200 frames...
# Saved 5300 frames...
# Saved 5400 frames...
# Saved 5500 frames...
# Saved 5600 frames...
# Saved 5700 frames...
# Saved 5800 frames...
# Saved 5900 frames...
# Saved 6000 frames...
# Saved 6100 frames...
# Saved 6200 frames...
# Saved 6300 frames...
# Saved 6400 frames...
# Saved 6500 frames...
# Saved 6600 frames...
# Saved 6700 frames...
# Saved 6800 frames...
# Saved 6900 frames...
# Saved 7000 frames...
# Saved 7100 frames...
# Saved 7200 frames...
# Saved 7300 frames...
# Saved 7400 frames...
# Saved 7500 frames...
# Saved 7600 frames...
# Saved 7700 frames...
# Saved 7800 frames...
# Saved 7900 frames...
# Saved 8000 frames...
# Saved 8100 frames...
# Saved 8200 frames...
# Saved 8300 frames...
# Saved 8400 frames...
# Saved 8500 frames...
# Saved 8600 frames...
# Saved 8700 frames...
# Saved 8800 frames...
# Saved 8900 frames...
# Saved 9000 frames...
# Saved 9100 frames...
# Saved 9200 frames...
# Saved 9300 frames...
# ...
# Saved 15000 frames...
# Saved 15100 frames...
# Saved 15200 frames...
# Saved 15300 frames...
# Saved 15400 frames...
# Saved 15500 frames...
# Saved 15600 frames...
# Saved 15700 frames...
# Saved 15800 frames...
# Saved 15900 frames...
# Saved 16000 frames...
# Saved 16100 frames...
# Saved 16200 frames...
# Saved 16300 frames...
# Saved 16400 frames...
# Saved 16500 frames...
# Saved 16600 frames...
# Saved 16700 frames...
# Saved 16800 frames...
# Saved 16900 frames...
# Saved 17000 frames...
# Saved 17100 frames...
# Saved 17200 frames...
# Saved 17300 frames...
# Saved 17400 frames...
# Saved 17500 frames...
# Saved 17600 frames...
# Saved 17700 frames...
# Saved 17800 frames...
# Saved 17900 frames...
# Saved 18000 frames...
# Saved 18100 frames...
# Saved 18200 frames...
# Saved 18300 frames...
# Saved 18400 frames...
# Saved 18500 frames...
# Saved 18600 frames...
# Saved 18700 frames...
# Saved 18800 frames...
# Saved 18900 frames...
# Saved 19000 frames...
# Saved 19100 frames...
# Saved 19200 frames...
# Saved 19300 frames...
# Saved 19400 frames...
# Saved 19500 frames...
# Saved 19600 frames...
# Saved 19700 frames...
# Saved 19800 frames...
# Saved 19900 frames...
# Saved 20000 frames...
# Saved 20100 frames...
# Saved 20200 frames...
# Saved 20300 frames...
# Saved 20400 frames...
# Saved 20500 frames...
# Saved 20600 frames...
# Saved 20700 frames...
# Saved 20800 frames...
# Saved 20900 frames...
# Saved 21000 frames...
# Saved 21100 frames...
# Saved 21200 frames...
# Saved 21300 frames...
# Saved 21400 frames...
# Saved 21500 frames...
# Saved 21600 frames...
# Saved 21700 frames...
# Saved 21800 frames...
# Saved 21900 frames...
# Saved 22000 frames...
# Saved 22100 frames...
# Saved 22200 frames...
# Saved 22300 frames...
# Saved 22400 frames...
# Saved 22500 frames...
# Saved 22600 frames...
# Finished. Scanned 24120 frames, saved 22695 distinct images.
# <class 'pandas.core.frame.DataFrame'>
# Index: 18950 entries, 776454 to 795403
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   video   18950 non-null  object
#  1   frame   18950 non-null  int64
#  2   class   18950 non-null  object
#  3   exist   18950 non-null  bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 610.7+ KB
# Saved 100 frames...
# Saved 200 frames...
# Saved 300 frames...
# Saved 400 frames...
# Saved 500 frames...
# Saved 600 frames...
# Saved 700 frames...
# Saved 800 frames...
# Saved 900 frames...
# Saved 1000 frames...
# Saved 1100 frames...
# Saved 1200 frames...
# Saved 1300 frames...
# Saved 1400 frames...
# Saved 1500 frames...
# Saved 1600 frames...
# Saved 1700 frames...
# Saved 1800 frames...
# Saved 1900 frames...
# Saved 2000 frames...
# Saved 2100 frames...
# Saved 2200 frames...
# Saved 2300 frames...
# Saved 2400 frames...
# Saved 2500 frames...
# Saved 2600 frames...
# Saved 2700 frames...
# Saved 2800 frames...
# Saved 2900 frames...
# Saved 3000 frames...
# Saved 3100 frames...
# Saved 3200 frames...
# Saved 3300 frames...
# Saved 3400 frames...
# Saved 3500 frames...
# Saved 3600 frames...
# Saved 3700 frames...
# Saved 3800 frames...
# Saved 3900 frames...
# Saved 4000 frames...
# Saved 4100 frames...
# Saved 4200 frames...
# Saved 4300 frames...
# Saved 4400 frames...
# Saved 4500 frames...
# Saved 4600 frames...
# Saved 4700 frames...
# Saved 4800 frames...
# Saved 4900 frames...
# Saved 5000 frames...
# Saved 5100 frames...
# Saved 5200 frames...
# Saved 5300 frames...
# Saved 5400 frames...
# Saved 5500 frames...
# Saved 5600 frames...
# Saved 5700 frames...
# Saved 5800 frames...
# Saved 5900 frames...
# Saved 6000 frames...
# Saved 6100 frames...
# Saved 6200 frames...
# Saved 6300 frames...
# Saved 6400 frames...
# Saved 6500 frames...
# Saved 6600 frames...
# Saved 6700 frames...
# Saved 6800 frames...
# Saved 6900 frames...
# Saved 7000 frames...
# Saved 7100 frames...
# Saved 7200 frames...
# Saved 7300 frames...
# Saved 7400 frames...
# Saved 7500 frames...
# Saved 7600 frames...
# Saved 7700 frames...
# Saved 7800 frames...
# Saved 7900 frames...
# Saved 8000 frames...
# Saved 8100 frames...
# Saved 8200 frames...
# Saved 8300 frames...
# Saved 8400 frames...
# Saved 8500 frames...
# Saved 8600 frames...
# Saved 8700 frames...
# Saved 8800 frames...
# Saved 8900 frames...
# Saved 9000 frames...
# Saved 9100 frames...
# Saved 9200 frames...
# Saved 9300 frames...
# Saved 9400 frames...
# Saved 9500 frames...
# Saved 9600 frames...
# Saved 9700 frames...
# Saved 9800 frames...
# Saved 9900 frames...
# Saved 10000 frames...
# Saved 10100 frames...
# Saved 10200 frames...
# Saved 10300 frames...
# Saved 10400 frames...
# Saved 10500 frames...
# Saved 10600 frames...
# Saved 10700 frames...
# Saved 10800 frames...
# Saved 10900 frames...
# Saved 11000 frames...
# Saved 11100 frames...
# Saved 11200 frames...
# Saved 11300 frames...
# Saved 11400 frames...
# Saved 11500 frames...
# Saved 11600 frames...
# Saved 11700 frames...
# Saved 11800 frames...
# Saved 11900 frames...
# Saved 12000 frames...
# Saved 12100 frames...
# Saved 12200 frames...
# Saved 12300 frames...
# Saved 12400 frames...
# Saved 12500 frames...
# Saved 12600 frames...
# Saved 12700 frames...
# Saved 12800 frames...
# Saved 12900 frames...
# Saved 13000 frames...
# Saved 13100 frames...
# Saved 13200 frames...
# Saved 13300 frames...
# Saved 13400 frames...
# Saved 13500 frames...
# Saved 13600 frames...
# Saved 13700 frames...
# Saved 13800 frames...
# Saved 13900 frames...
# Saved 14000 frames...
# Saved 14100 frames...
# Saved 14200 frames...
# Saved 14300 frames...
# Saved 14400 frames...
# Saved 14500 frames...
# Saved 14600 frames...
# Saved 14700 frames...
# Saved 14800 frames...
# Saved 14900 frames...
# Saved 15000 frames...
# Saved 15100 frames...
# Saved 15200 frames...
# Saved 15300 frames...
# Saved 15400 frames...
# Saved 15500 frames...
# Saved 15600 frames...
# Saved 15700 frames...
# Saved 15800 frames...
# Saved 15900 frames...
# Saved 16000 frames...
# Saved 16100 frames...
# Saved 16200 frames...
# Saved 16300 frames...
# Saved 16400 frames...
# Saved 16500 frames...
# Saved 16600 frames...
# Saved 16700 frames...
# Saved 16800 frames...
# Saved 16900 frames...
# Saved 17000 frames...
# Saved 17100 frames...
# Saved 17200 frames...
# Saved 17300 frames...
# Saved 17400 frames...
# Saved 17500 frames...
# Saved 17600 frames...
# Saved 17700 frames...
# Saved 17800 frames...
# Saved 17900 frames...
# Saved 18000 frames...
# Saved 18100 frames...
# Saved 18200 frames...
# Saved 18300 frames...
# Finished. Scanned 18950 frames, saved 18344 distinct images.
# <class 'pandas.core.frame.DataFrame'>
# Index: 14115 entries, 385004 to 399118
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   video   14115 non-null  object
#  1   frame   14115 non-null  int64
#  2   class   14115 non-null  object
#  3   exist   14115 non-null  bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 454.9+ KB
# Saved 100 frames...
# Saved 200 frames...
# Saved 300 frames...
# Saved 400 frames...
# Saved 500 frames...
# Saved 600 frames...
# Saved 700 frames...
# Saved 800 frames...
# Saved 900 frames...
# Saved 1000 frames...
# Saved 1100 frames...
# Saved 1200 frames...
# Saved 1300 frames...
# Saved 1400 frames...
# Saved 1500 frames...
# Saved 1600 frames...
# Saved 1700 frames...
# Saved 1800 frames...
# Saved 1900 frames...
# Saved 2000 frames...
# Saved 2100 frames...
# Saved 2200 frames...
# Saved 2300 frames...
# Saved 2400 frames...
# Saved 2500 frames...
# Saved 2600 frames...
# Saved 2700 frames...
# Saved 2800 frames...
# Saved 2900 frames...
# Saved 3000 frames...
# Saved 3100 frames...
# Saved 3200 frames...
# Saved 3300 frames...
# Saved 3400 frames...
# Saved 3500 frames...
# Saved 3600 frames...
# Saved 3700 frames...
# Saved 3800 frames...
# Saved 3900 frames...
# Saved 4000 frames...
# Saved 4100 frames...
# Saved 4200 frames...
# Saved 4300 frames...
# Saved 4400 frames...
# Saved 4500 frames...
# Saved 4600 frames...
# Saved 4700 frames...
# Saved 4800 frames...
# Saved 4900 frames...
# Saved 5000 frames...
# Saved 5100 frames...
# Saved 5200 frames...
# Saved 5300 frames...
# Saved 5400 frames...
# Saved 5500 frames...
# Saved 5600 frames...
# Saved 5700 frames...
# Saved 5800 frames...
# Saved 5900 frames...
# Saved 6000 frames...
# Saved 6100 frames...
# Saved 6200 frames...
# Saved 6300 frames...
# Saved 6400 frames...
# Saved 6500 frames...
# Saved 6600 frames...
# Saved 6700 frames...
# Saved 6800 frames...
# Saved 6900 frames...
# Saved 7000 frames...
# Saved 7100 frames...
# Saved 7200 frames...
# Saved 7300 frames...
# Saved 7400 frames...
# Saved 7500 frames...
# Saved 7600 frames...
# Saved 7700 frames...
# Saved 7800 frames...
# Saved 7900 frames...
# Saved 8000 frames...
# Saved 8100 frames...
# Saved 8200 frames...
# Saved 8300 frames...
# Saved 8400 frames...
# Saved 8500 frames...
# Saved 8600 frames...
# Saved 8700 frames...
# Saved 8800 frames...
# Saved 8900 frames...
# Saved 9000 frames...
# Saved 9100 frames...
# Saved 9200 frames...
# Saved 9300 frames...
# Saved 9400 frames...
# Saved 9500 frames...
# Saved 9600 frames...
# Saved 9700 frames...
# Saved 9800 frames...
# Saved 9900 frames...
# Saved 10000 frames...
# Saved 10100 frames...
# Saved 10200 frames...
# Saved 10300 frames...
# Saved 10400 frames...
# Saved 10500 frames...
# Saved 10600 frames...
# Saved 10700 frames...
# Saved 10800 frames...
# Saved 10900 frames...
# Saved 11000 frames...
# Saved 11100 frames...
# Saved 11200 frames...
# Saved 11300 frames...
# Saved 11400 frames...
# Saved 11500 frames...
# Saved 11600 frames...
# Saved 11700 frames...
# Saved 11800 frames...
# Saved 11900 frames...
# Saved 12000 frames...
# Saved 12100 frames...
# Saved 12200 frames...
# Saved 12300 frames...
# Saved 12400 frames...
# Saved 12500 frames...
# Saved 12600 frames...
# Saved 12700 frames...
# Saved 12800 frames...
# Saved 12900 frames...
# Saved 13000 frames...
# Saved 13100 frames...
# Saved 13200 frames...
# Finished. Scanned 14115 frames, saved 13259 distinct images.
# <class 'pandas.core.frame.DataFrame'>
# Index: 17970 entries, 110360 to 128329
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   video   17970 non-null  object
#  1   frame   17970 non-null  int64
#  2   class   17970 non-null  object
#  3   exist   17970 non-null  bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 579.1+ KB
# Saved 100 frames...
# Saved 200 frames...
# Saved 300 frames...
# Saved 400 frames...
# Saved 500 frames...
# Saved 600 frames...
# Saved 700 frames...
# Saved 800 frames...
# Saved 900 frames...
# Saved 1000 frames...
# Saved 1100 frames...
# Saved 1200 frames...
# Saved 1300 frames...
# Saved 1400 frames...
# Saved 1500 frames...
# Saved 1600 frames...
# Saved 1700 frames...
# Saved 1800 frames...
# Saved 1900 frames...
# Saved 2000 frames...
# Saved 2100 frames...
# Saved 2200 frames...
# Saved 2300 frames...
# Saved 2400 frames...
# Saved 2500 frames...
# Saved 2600 frames...
# Saved 2700 frames...
# Saved 2800 frames...
# Saved 2900 frames...
# Saved 3000 frames...
# Saved 3100 frames...
# Saved 3200 frames...
# Saved 3300 frames...
# Saved 3400 frames...
# Saved 3500 frames...
# Saved 3600 frames...
# Saved 3700 frames...
# Saved 3800 frames...
# Saved 3900 frames...
# Saved 4000 frames...
# Saved 4100 frames...
# Saved 4200 frames...
# Saved 4300 frames...
# Saved 4400 frames...
# Saved 4500 frames...
# Saved 4600 frames...
# Saved 4700 frames...
# Saved 4800 frames...
# Saved 4900 frames...
# Saved 5000 frames...
# Saved 5100 frames...
# Saved 5200 frames...
# Saved 5300 frames...
# Saved 5400 frames...
# Saved 5500 frames...
# Saved 5600 frames...
# Saved 5700 frames...
# Saved 5800 frames...
# Saved 5900 frames...
# Saved 6000 frames...
# Saved 6100 frames...
# Saved 6200 frames...
# Saved 6300 frames...
# Saved 6400 frames...
# Saved 6500 frames...
# Saved 6600 frames...
# Saved 6700 frames...
# Saved 6800 frames...
# Saved 6900 frames...
# Saved 7000 frames...
# Saved 7100 frames...
# Saved 7200 frames...
# Saved 7300 frames...
# Saved 7400 frames...
# Saved 7500 frames...
# Saved 7600 frames...
# Saved 7700 frames...
# Saved 7800 frames...
# Saved 7900 frames...
# Saved 8000 frames...
# Saved 8100 frames...
# Saved 8200 frames...
# Saved 8300 frames...
# Saved 8400 frames...
# Saved 8500 frames...
# Saved 8600 frames...
# Saved 8700 frames...
# Saved 8800 frames...
# Saved 8900 frames...
# Saved 9000 frames...
# Saved 9100 frames...
# Saved 9200 frames...
# Saved 9300 frames...
# Saved 9400 frames...
# Saved 9500 frames...
# Saved 9600 frames...
# Saved 9700 frames...
# Saved 9800 frames...
# Saved 9900 frames...
# Saved 10000 frames...
# Saved 10100 frames...
# Saved 10200 frames...
# Saved 10300 frames...
# Saved 10400 frames...
# Saved 10500 frames...
# Saved 10600 frames...
# Saved 10700 frames...
# Saved 10800 frames...
# Saved 10900 frames...
# Saved 11000 frames...
# Saved 11100 frames...
# Saved 11200 frames...
# Saved 11300 frames...
# Saved 11400 frames...
# Saved 11500 frames...
# Saved 11600 frames...
# Saved 11700 frames...
# Saved 11800 frames...
# Saved 11900 frames...
# Saved 12000 frames...
# Saved 12100 frames...
# Saved 12200 frames...
# Saved 12300 frames...
# Saved 12400 frames...
# Saved 12500 frames...
# Saved 12600 frames...
# Saved 12700 frames...
# Saved 12800 frames...
# Saved 12900 frames...
# Saved 13000 frames...
# Saved 13100 frames...
# Saved 13200 frames...
# Saved 13300 frames...
# Saved 13400 frames...
# Saved 13500 frames...
# Saved 13600 frames...
# Saved 13700 frames...
# Saved 13800 frames...
# Saved 13900 frames...
# Saved 14000 frames...
# Saved 14100 frames...
# Saved 14200 frames...
# Saved 14300 frames...
# Saved 14400 frames...
# Saved 14500 frames...
# Saved 14600 frames...
# Saved 14700 frames...
# Saved 14800 frames...
# Saved 14900 frames...
# Saved 15000 frames...
# Saved 15100 frames...
# Saved 15200 frames...
# Saved 15300 frames...
# Saved 15400 frames...
# Saved 15500 frames...
# Saved 15600 frames...
# Saved 15700 frames...
# Saved 15800 frames...
# Saved 15900 frames...
# Saved 16000 frames...
# Saved 16100 frames...
# Saved 16200 frames...
# Saved 16300 frames...
# Saved 16400 frames...
# Saved 16500 frames...
# Saved 16600 frames...
# Saved 16700 frames...
# Saved 16800 frames...
# Finished. Scanned 17970 frames, saved 16850 distinct images.
# <class 'pandas.core.frame.DataFrame'>
# Index: 8649 entries, 914133 to 922781
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   video   8649 non-null   object
#  1   frame   8649 non-null   int64
#  2   class   8649 non-null   object
#  3   exist   8649 non-null   bool
# dtypes: bool(1), int64(1), object(2)
# memory usage: 278.7+ KB
# Saved 100 frames...
# Saved 200 frames...
# Saved 300 frames...
# Saved 400 frames...
# Saved 500 frames...
# Saved 600 frames...
# Saved 700 frames...
# Saved 800 frames...
# Saved 900 frames...
# Saved 1000 frames...
# Saved 1100 frames...
# Saved 1200 frames...
# Saved 1300 frames...
# Saved 1400 frames...
# Saved 1500 frames...
# Saved 1600 frames...
# Saved 1700 frames...
# Saved 1800 frames...
# Saved 1900 frames...
# Saved 2000 frames...
# Saved 2100 frames...
# Saved 2200 frames...
# Saved 2300 frames...
# Saved 2400 frames...
# Saved 2500 frames...
# Saved 2600 frames...
# Saved 2700 frames...
# Saved 2800 frames...
# Saved 2900 frames...
# Saved 3000 frames...
# Saved 3100 frames...
# Saved 3200 frames...
# Saved 3300 frames...
# Saved 3400 frames...
# Saved 3500 frames...
# Saved 3600 frames...
# Saved 3700 frames...
# Saved 3800 frames...
# Saved 3900 frames...
# Saved 4000 frames...
# Saved 4100 frames...
# Saved 4200 frames...
# Saved 4300 frames...
# Saved 4400 frames...
# Saved 4500 frames...
# Saved 4600 frames...
# Saved 4700 frames...
# Saved 4800 frames...
# Saved 4900 frames...
# Saved 5000 frames...
# Saved 5100 frames...
# Saved 5200 frames...
# Saved 5300 frames...
# Saved 5400 frames...
# Saved 5500 frames...
# Saved 5600 frames...
# Saved 5700 frames...
# Saved 5800 frames...
# Saved 5900 frames...
# Saved 6000 frames...
# Saved 6100 frames...
# Saved 6200 frames...
# Saved 6300 frames...
# Saved 6400 frames...
# Saved 6500 frames...
# Saved 6600 frames...
# Saved 6700 frames...
# Saved 6800 frames...
# Saved 6900 frames...
# Saved 7000 frames...
# Saved 7100 frames...
# Saved 7200 frames...
# Saved 7300 frames...
# Saved 7400 frames...
# Saved 7500 frames...
# Saved 7600 frames...
# Saved 7700 frames...
# Saved 7800 frames...
# Saved 7900 frames...
# Finished. Scanned 8649 frames, saved 7963 distinct images.
# C:\Users\Luis Miguel\AppData\Local\Temp\ipykernel_14308\2646245612.py:3: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df_images.groupby('video', group_keys=False).apply(
# Empty DataFrame
# Columns: []
# Index: []
